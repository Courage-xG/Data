# %%
#import modules
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
from matplotlib.patches import Arc, Rectangle, Circle

# %%
df = pd.read_csv('C:\\Users\\HP\\Downloads\\MYDATASPORT (4).csv') 
df
# Out:
#                             Match      Player from                Action  \
# 0    Ikorodu City vs Remo Stars B   Tosin Oyedekun      Chance Set Piece
# 1    Ikorodu City vs Remo Stars B  Harrison Uzondu          Intervention
# 2    Ikorodu City vs Remo Stars B  Harrison Uzondu          Intervention
# 3    Ikorodu City vs Remo Stars B   Tosin Oyedekun         Foul Received
# 4    Ikorodu City vs Remo Stars B    Farouq Farouq                  Loss
# ..                            ...              ...                   ...
# 249  Ikorodu City vs Remo Stars B      Yusuf  Rauf                  Save
# 250  Ikorodu City vs Remo Stars B      Yusuf  Rauf          Shot Against
# 251  Ikorodu City vs Remo Stars B  Harrison Uzondu  Successful Shot Pass
# 252  Ikorodu City vs Remo Stars B    Farouq Farouq   Successful Key Pass
# 253  Ikorodu City vs Remo Stars B   Tosin Oyedekun       Shot off target
#
#      X player from  Y player from  Minute  Second       player to  \
# ...

# %%
#plotting Kelechi Onwe's progressive pass data

fig, ax = plt.subplots(figsize=(13.5, 8))
fig.set_facecolor('#22312b')
ax.patch.set_facecolor('#22312b')

# Define the pitch type
pitch_type = 'statsbomb'  # or 'opta'

# Create the pitch based on the type
pitch = Pitch(
    pitch_type=pitch_type,
    pitch_color='#22312b',
    line_color='#c7d5cc',
)

# Draw the pitch on the ax figure as well as invert the axis for this specific pitch
pitch.draw(ax=ax)

# Conditionally invert the y-axis based on pitch type
if pitch_type == 'statsbomb':
    plt.gca().invert_yaxis()  # Only invert for statsbomb pitch type

# Adjust coordinates based on pitch type
x_scale = 1.2 if pitch_type == 'statsbomb' else 1
y_scale = 0.8 if pitch_type == 'statsbomb' else 1
    
# Plot each pass with the corrected condition
for i in range(len(df['X player from'])):
    x_start = df['X player from'].iloc[i] * x_scale
    y_start = df['Y player from'].iloc[i] * y_scale
    x_end = df['X player to'].iloc[i] * x_scale
    y_end = df['Y player from'].iloc[i] * y_scale
    
    if df['Action'].iloc[i] == 'Successful Progressive Pass' and df['Player from'].iloc[i] == 'Kelechi Onwe':
        plt.plot(('X player from', 'X player to'), ('Y player from', 'Y player to'), color='green')
        plt.scatter('X player from', 'Y player from', color='green')
    elif df['Action'].iloc[i] == 'Unsuccessful Progressive Pass' and df['Player from'].iloc[i] == 'Kelechi Onwe':
        plt.plot(('X player from', 'X player to'), ('Y player from', 'Y player to'), color='red')
        plt.scatter('X player from', 'Y player from', color='red')

plt.title('Progressive Passes by Kelechi Onwe Successful Progressive Pass: Green | Unsuccessful Progressive Pass: Red',
    color='white', size=13)
plt.show()
# Out:
#   Cell In[77], line 38
#     else df['Action'].iloc[i] == 'Unsuccessful Progressive Pass' and df['Player from'].iloc[i] == 'Kelechi Onwe':
#          ^
# SyntaxError: expected ':'

# %%
print(df.columns)
# Out:
# Index(['Match', 'Player from', 'Action', 'X player from', 'Y player from',
#        'Minute', 'Second', 'player to', 'X player to', 'Y player to', 'Half',
#        'Field Side', 'Unnamed: 12'],
#       dtype='object')

# %%
# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                           Match      Player from            Action  \
# 0  Ikorodu City vs Remo Stars B   Tosin Oyedekun  Chance Set Piece
# 1  Ikorodu City vs Remo Stars B  Harrison Uzondu      Intervention
# 2  Ikorodu City vs Remo Stars B  Harrison Uzondu      Intervention
# 3  Ikorodu City vs Remo Stars B   Tosin Oyedekun     Foul Received
# 4  Ikorodu City vs Remo Stars B    Farouq Farouq              Loss
#
#    X player from  Y player from  Minute  Second player to  X player to  \
# 0             72             72       0      25       NaN            0
# 1             25             95       1      54       NaN            0
# 2              3             91       2      15       NaN            0
# 3             40             89       2      37       NaN            0
# 4             50             50       2      56       NaN            0
#
#    Y player to  Half Field Side  Unnamed: 12
# 0            0     1          L          NaN
# ...

# %%
# Display data types and some sample values for each column
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Match          254 non-null    object
#  1   Player from    254 non-null    object
#  2   Action         254 non-null    object
#  3   X player from  254 non-null    int64
#  4   Y player from  254 non-null    int64
#  5   Minute         254 non-null    int64
#  6   Second         254 non-null    int64
#  7   player to      92 non-null     object
#  8   X player to    254 non-null    int64
#  9   Y player to    254 non-null    int64
#  10  Half           254 non-null    int64
#  11  Field Side     254 non-null    object
#  12  Unnamed: 12    0 non-null      float64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 25.9+ KB
# None
